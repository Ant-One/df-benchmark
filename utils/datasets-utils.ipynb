# %%
import json

# %%
with open("datasets_json/FRAll_ff.json") as file:
    fr_all = json.load(file)

with open("datasets_json/FSAll_ff.json") as file:
    fs_all = json.load(file)

# %%
label_fs = "FSAll_fake"
label_fr = "FRAll_fake"

# %%
new_dataset = {
    "FSvFR_ff": {
        "FSAll_Fake": {
            "train": fs_all["FSAll_ff"]["FSAll_Fake"]["train"],
            "val": fs_all["FSAll_ff"]["FSAll_Fake"]["val"]
        },
        "FRAll_Fake": {
            "train": fr_all["FRAll_ff"]["FRAll_Fake"]["train"],
            "val": fr_all["FRAll_ff"]["FRAll_Fake"]["val"]
        }
    }
}

# %%
with open("datasets_json/FSvFR.json", "x") as file:
    json.dump(new_dataset, file, indent=4)

# %%
with open("datasets_json/FRAll_cdf.json") as file:
    fr_all = json.load(file)

with open("datasets_json/FSAll_cdf.json") as file:
    fs_all = json.load(file)

label_fs = "FSAll_fake"
label_fr = "FRAll_fake"

new_dataset = {
    "FSvFR_cdf": {
        "FSAll_Fake": {
            "test": fs_all["FSAll_cdf"]["FSAll_Fake"]["test"]
        },
        "FRAll_Fake": {
            "test": fr_all["FRAll_cdf"]["FRAll_Fake"]["test"],
        }
    }
}
with open("datasets_json/FSvFR_cdf.json", "x") as file:
    json.dump(new_dataset, file, indent=4)
